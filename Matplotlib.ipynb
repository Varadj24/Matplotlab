# %%
#Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib

# %%
'''
  Matplotlib is a popular data visualization library in Python that provides an object-oriented API for embedding plots into applications that use general-purpose 
GUI toolkits like Tkinter, wxPython, Qt, or GTK. It also provides an interface for embedding plots into web applications using general-purpose web application servers like Django or Flask.

Matplotlib is used for creating static, interactive, and animated plots in Python. 
It is extensively used for visualizing data and results in various fields such as scientific research, engineering, data science, and machine learning. \
The library is highly customizable and can be used to create a wide variety of plots and charts.

Line Plot 
Scatter Plot
Bar Plot 
Histogram 
Pie Chart'''

# %%
#Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, 50)

plt.scatter(x, y, color='#5DD0FA', label='Data Points')

plt.title('Scatter Plot Example')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

plt.legend()
plt.grid(True)  
plt.show()

# %%
#Q3: Why is the subplot() function used? Draw four line plots using the subplot() function

# %%
x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])

y2 = np.array([50, 20, 40, 20, 60, 70])

y3 = np.array([10, 20, 30, 40, 50, 60])

y4 = np.array([200, 350, 250, 550, 450, 150])

plt.figure(figsize=(12, 8))


plt.subplot(2, 2, 1)  
plt.plot(x, y1, color='#9C4FDB')
plt.title('Line Plot 1')


plt.subplot(2, 2, 2)
plt.plot(x, y2, color='#F99D00')
plt.title('Line Plot 2')

# Subplot 3
plt.subplot(2, 2, 3)  
plt.plot(x, y3, color='#5AF569')
plt.title('Line Plot 3')


plt.subplot(2, 2, 4)  
plt.plot(x, y4, color='#61E1E5')
plt.title('Line Plot 4')


plt.tight_layout()


plt.show()

# %%
#Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot. 
#import numpy as np
#company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#profit = np.array([3000, 8000, 1000, 10000])

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])


plt.figure(figsize=(8, 6))
plt.bar(company, profit, color='skyblue')
plt.xlabel('Company')
plt.ylabel('Profit (in millions)')
plt.title('Bar Plot')
plt.xticks(rotation=45)  
plt.show()


plt.figure(figsize=(8, 6))
plt.barh(company, profit, color='green')
plt.ylabel('Company')
plt.xlabel('Profit (in millions)')
plt.title('Horizontal Bar Plot')
plt.show()

# %%
#Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#box1 = np.random.normal(100, 10, 200)
#box2 = np.random.normal(90, 20, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Create a box plot
plt.figure(figsize=(8, 6))
plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'])
plt.xlabel('Box')
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()
